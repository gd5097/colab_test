# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/open_source_programming
# Out:
# /content/drive/MyDrive/open_source_programming

# %%
# !git clone https://github.com/gd5097/open_source_programming_2023_fall_semester.git
# Out:
# fatal: destination path 'open_source_programming_2023_fall_semester' already exists and is not an empty directory.

# %%
cd open_source_programming_2023_fall_semester
# Out:
# /content/drive/MyDrive/open_source_programming/open_source_programming_2023_fall_semester

# %%
# !git config --global user.email 'gd5097@hanmail.net'
# !git config --global user.name 'jab_cho'

# %%
# !git pull origin main
# Out:
# From https://github.com/gd5097/open_source_programming_2023_fall_semester
#  * branch            main       -> FETCH_HEAD
# Updating a8e47f0..d5adc1e
# Fast-forward
#  README.md    | 4 ++--
#  main.py      | 3 +++
#  testfile.txt | 3 +--
#  testtext.txt | 1 +
#  4 files changed, 7 insertions(+), 4 deletions(-)
#  create mode 100644 main.py
#  create mode 100644 testtext.txt

# %%
ls -al
# Out:
# total 9
# drwx------ 6 root root 4096 Sep 26 04:31 .git/
# drwx------ 2 root root 4096 Sep 19 04:21 .ipynb_checkpoints/
# -rw------- 1 root root  185 Sep 19 05:11 README.md
# -rw------- 1 root root   35 Sep 19 05:13 testfile.txt

# %%
# !git config pull.rebase false

# %%
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
# Out:
# usage: git push [<options>] [<repository> [<refspec>...]]
#
#     -v, --verbose         be more verbose
#     -q, --quiet           be more quiet
#     --repo <repository>   repository
#     --all                 push all refs
#     --mirror              mirror all refs
#     -d, --delete          delete refs
#     --tags                push tags (can't be used with --all or --mirror)
#     -n, --dry-run         dry run
#     --porcelain           machine-readable output
#     -f, --force           force updates
#     --force-with-lease[=<refname>:<expect>]
#                           require old value of ref to be at this value
#     --force-if-includes   require remote updates to be integrated locally
#     --recurse-submodules (check|on-demand|no)
#                           control recursive pushing of submodules
#     --thin                use thin pack
#     --receive-pack <receive-pack>
#                           receive pack program
#     --exec <receive-pack>
# ...

# %%
# !echo "https://gd5097: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@github.com" > ~/.git-credentials
